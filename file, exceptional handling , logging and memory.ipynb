# %% [markdown]
# **1  What is the difference between interpreted and compiled languages?)**
#
# Ans:- an interpreter reads and executes the code line by line, while the program is running.
#
# Compiled languages are programming languages where the code you write is translated into machine code (binary 0s and 1s) before the program runs.

# %% [markdown]
# **2 What is exception handling in Python?**
#
# Ans:- Exception handling in Python is a way to manage errors that occur while a program is running , so your program doesn’t crash suddenly.

# %% [markdown]
# **3  What is the purpose of the finally block in exception handling?**
#
# Ans: The purpose of the finally block in exception handling is to define a section of code that always executes, no matter what happens in the try or except blocks.

# %% [markdown]
# **4  What is logging in Python?**
#
# Ans:- Logging in Python is a way to record (log) messages that describe what’s happening in your program while it runs.

# %% [markdown]
# **5  What is the significance of the __del__ method in Python?**
#
# Ans:- It is called automatically when an object is about to be destroyed, meaning when it’s no longer needed and the Python garbage collector is about to free the memory that the object occupes.

# %% [markdown]
# **6  What is the difference between import and from ... import in Python?**
#
# Ans:- The import statement imports the entire module.
# You then access its functions, classes, or variables using dot notation (module_name.item).
#
# from ... import statement
#
# The from ... import form imports specific items (functions, classes, or variables) directly from a module.

# %% [markdown]
# **7  How can you handle multiple exceptions in Python?**
#
# Ans:- You can have multiple except blocks to handle different types of errors in different ways.
#
# (1) If the user enters a non-number → ValueError block runs.
# (2) If the user enters 0 → ZeroDivisionError block runs.

# %% [markdown]
# **8 What is the purpose of the with statement when handling files in Python?**
#
# Ans:- Automatic cleanup: You don’t need to explicitly call file.close().
#
# Exception safety: The file is closed even if an exception occurs inside the block.
#
# Cleaner code: Reduces boilerplate code and makes it more readable.

# %% [markdown]
# **9 What is the difference between multithreading and multiprocessing?**
#
# Ans:- Multithreading in Python is a technique that allows a program to run multiple threads of execution concurrently within the same process.
#
# Multiprocessing in Python is a technique that allows a program to run multiple processes simultaneously, each with its own Python interpreter and memory space.

# %% [markdown]
# **10  What are the advantages of using logging in a program?**
#
# Ans:- 1. Debugging and Troubleshooting:- Logs record detailed information about program execution.
# 2. Persistence:- Logs can be saved to files instead of just appearing in the console.
# 3. Different Levels of Severity:- Logging supports levels like DEBUG, INFO, WARNING, ERROR, CRITICAL.
# 4. Flexibility:- Logs can be directed to multiple outputs: console, files, network sockets, or external monitoring systems.

# %% [markdown]
# **11  What is memory management in Python?**
#
# Ans:- Memory management in Python refers to the process by which Python allocates,tracks, and frees memory for objects used in a program. Python manages memory automatically, which means developers usually don’t need to manually allocate or deallocate memory like in languages such as C or C++.

# %% [markdown]
# **12  What are the basic steps involved in exception handling in Python?**
#
# Ans:- The basic steps involve using the try, except, else, and finally blocks.

# %% [markdown]
# **13 Why is memory management important in Python?**
#
# Ans:- Memory management is crucial in Python because it ensures that a program runs efficiently, safely, and reliably. Without proper memory management, programs can become slow, crash, or behave unpredictably.

# %% [markdown]
# **14  What is the role of try and except in exception handling?**
#
# Ans:- . try block:-
# The try block contains the code that might raise an exception.Python monitors this block for any runtime errors.
#
# except block:-
# The except block catches and handles the exception raised in the try block.You can handle specific exceptions or use a generic exception.

# %% [markdown]
# **15  How does Python's garbage collection system work?**
#
# Ans:- Python’s garbage collection (GC) system is responsible for automatically managing memory by reclaiming memory from objects that are no longer in use. This helps prevent memory leaks and makes programming easier.

# %% [markdown]
# **16  What is the purpose of the else block in exception handling?**
#
# Ans:- the else block in exception handling is an optional block that runs only if no exception occurs in the try block.

# %% [markdown]
# **17  What are the common logging levels in Python?**
#
# Ans:- Logging levels let you categorize messages by importance, making it easier to monitor, debug, and maintain your program.

# %% [markdown]
# **18  What is the difference between os.fork() and multiprocessing in Python?**
#
# Ans:- os.fork():- is a low-level system call available on Unix/Linux systems.
#
# multiprocessing:- High-level Python module for creating processes in a cross-platform like (Windows, Linux, Mac).

# %% [markdown]
# **19  What is the importance of closing a file in Python?**
#
# Ans:- Closing a file in Python is crucial for proper resource management, data integrity, and program stability. When you open a file, Python allocates system resources for it . If you don’t close it, these resources may remain occupied unnecessarily, which can lead to problems.

# %% [markdown]
# **20 What is the difference between file.read() and file.readline() in Python?**
#
# Ans:- **file.read():-**
#
# Reads the entire content of the file.
#
# Returns a string containing all the text.
#
# Useful when you want to process the whole file at once.
#
#  **file.readline():-**
#
#  Reads one line at a time from the file.
#
# Each call returns the next line as a string, including the newline character \n.
#
# Useful when you want to process the file line by line, saving memory for large files.

# %% [markdown]
# **21  What is the logging module in Python used for?**
#
# Ans:- The logging module in Python is used for tracking events that happen while a program runs. It provides a flexible framework for recording messages, which can help with debugging, monitoring, and auditing programs.

# %% [markdown]
# **22  What is the os module in Python used for in file handling?**
#
# Ans:- The os module in Python provides a way to interact with the operating system and is widely used in file and directory handling. It allows you to perform tasks like creating, deleting, renaming files and directories, and accessing system-level information.

# %% [markdown]
# **23  What are the challenges associated with memory management in Python?**
#
# Ans:-
# 1. Circular References.
# 2. Memory Leaks.
# 3. Large Data Structures.
# 4. Inefficient Garbage Collection.
# 5. Non-deterministic Cleanup.
# 6. External Resources.

# %% [markdown]
# **24 How do you raise an exception manually in Python?**
#
# Ans:- you can raise an exception manually using the raise statement. This is useful when you want your program to stop execution and signal that something went wrong under certain conditions.

# %% [markdown]
# **25  Why is it important to use multithreading in certain applications?**
#
# Ans:- Using multithreading in certain applications is important because it allows a program to perform multiple tasks concurrently, improving efficiency and responsiveness.

# %%
## Practical Questions

# %%
## 1. How can you open a file for writing in Python and write a string to it.

# Open a file in write mode
file = open("example.txt", "w")

# Write a string to the file
file.write("Hello, world!\n")

# Close the file
file.close()

# %%
## 2. Write a Python program to read the contents of a file and print each line.

with open("example.txt", "r") as file:

    for line in file:
        print(line.strip())
# Out:
# Hello, world!

# %%
## 3 How would you handle a case where the file doesn't exist while trying to open it for reading?

try:
    with open("example.txt", "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Hello, world!

# %%
## 4 Write a Python script that reads from one file and writes its content to another file.

source_file = "source.txt"
destination_file = "destination.txt"

try:
    # Open the source file in read mode
    with open(source_file, "r") as src:
        # Open the destination file in write mode
        with open(destination_file, "w") as dest:
            # Read each line from the source and write it to the destination
            for line in src:
                dest.write(line)
    print(f"Contents of '{source_file}' have been copied to '{destination_file}'.")

except FileNotFoundError:
    print(f"Error: The file '{source_file}' does not exist.")
# Out:
# Error: The file 'source.txt' does not exist.

# %%
## 5 How would you catch and handle division by zero error in Python.

try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Error: Cannot divide by zero!

# %%
## 6  Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging

# Set up logging to a file
logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero occurred!")
    print("An error occurred. Check 'error.log' for details.")
# Out:
# ERROR:root:Division by zero occurred!
# An error occurred. Check 'error.log' for details.

# %%
## 7 How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module.

import logging

# Configure logging
logging.basicConfig(
    filename="app.log",      # Log file
    level=logging.DEBUG,      # Minimum level to log
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# %%
## 8  Write a program to handle a file opening error using exception handling.

try:
    file = open("example.txt", "r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Hello, world!

# %%
##  9 How can you read a file line by line and store its content in a list in Python.

lines = []

with open("example.txt", "r") as file:
    for line in file:
        lines.append(line.strip())  # strip() removes the newline character

print(lines)
# Out:
# ['Hello, world!']

# %%
## 10 How can you append data to an existing file in Python?

with open("example.txt", "a") as file:
    file.write("This is a new line.\n")
    file.write("Another line added.\n")

# %%
## 11 Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

my_dict = {"asif": "assu", "age": 25, "city": "sasaram"}

try:

    print("Country:", my_dict["country"])
except KeyError:
    print("Error: The key 'country' does not exist in the dictionary.")
# Out:
# Error: The key 'country' does not exist in the dictionary.

# %%
## 12 Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

try:
    # Get user input
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))

    # Divide the numbers
    result = num1 / num2
    print("Result:", result)

    # Access a dictionary key
    my_dict = {"name": "Alice", "age": 25}
    print("City:", my_dict["city"])

except ZeroDivisionError:
    print("Error: Cannot divide by zero!")

except ValueError:
    print("Error: Please enter valid numbers!")

except KeyError:
    print("Error: The key does not exist in the dictionary!")
# Out:
# Enter a number: 12
# Enter another number: 15
# Result: 0.8
# Error: The key does not exist in the dictionary!

# %%
##  13 How would you check if a file exists before attempting to read it in Python.

import os

filename = "example.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"The file '{filename}' does not exist.")
# Out:
# Hello, world!
# This is a new line.
# Another line added.
# This is a new line.
# Another line added.

# %%
## 14 Write a program that uses the logging module to log both informational and error messages.

import logging

# Set up logging
logging.basicConfig(filename="app.log", level=logging.INFO)

logging.info("Program started")

try:
    result = 10 / 0  # This will cause an error
    logging.info(f"Result is {result}")
except ZeroDivisionError:
    logging.error("Error: Division by zero occurred")

logging.info("Program finished")
# Out:
# ERROR:root:Error: Division by zero occurred

# %%
## 15 Write a Python program that prints the content of a file and handles the case when the file is empty.

filename = "example.txt"

try:
    with open(filename, "r") as file:
        content = file.read()
        if content:  # Check if the file is not empty
            print("File contents:")
            print(content)
        else:
            print(f"The file '{filename}' is empty.")
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# File contents:
# Hello, world!
# This is a new line.
# Another line added.
# This is a new line.
# Another line added.

# %%
## 16 Demonstrate how to use memory profiling to check the memory usage of a small program.

from memory_profiler import profile

@profile
def memory_intensive_function():
    # Create a large list
    large_list = [i for i in range(1000000)]

    # Add more data to increase memory usage
    large_list.extend([i * 2 for i in range(500000)])

    # Remove some elements to observe memory deallocation
    del large_list[500000:]

    return len(large_list)

if __name__ == "__main__":
    result = memory_intensive_function()
    print(f"Final list length: {result}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4109242050.py in <cell line: 0>()
#       1 ## 16 Demonstrate how to use memory profiling to check the memory usage of a small program.
#       2
# ----> 3 from memory_profiler import profile
#       4
#       5 @profile
#
# ModuleNotFoundError: No module named 'memory_profiler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
## 17 Write a Python program to create and write a list of numbers to a file, one number per line.

# List of numbers
numbers = [10, 20, 30, 40, 50]

# Open a file in write mode
with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")  # Write each number on a new line

print("Numbers have been written to 'numbers.txt'.")
# Out:
# Numbers have been written to 'numbers.txt'.

# %%
## 18 How would you implement a basic logging setup that logs to a file with rotation after 1MB.

import logging
from logging.handlers import RotatingFileHandler

# Create a logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.INFO)  # Log INFO and above

# Create a rotating file handler
handler = RotatingFileHandler(
    "app.log", maxBytes=1_000_000, backupCount=3  # 1 MB, keep 3 backup files
)

# Set log message format
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

# Add handler to the logger
logger.addHandler(handler)

# Example log messages
logger.info("Program started")
logger.warning("This is a warning")
logger.error("This is an error")
# Out:
# INFO:MyLogger:Program started
# WARNING:MyLogger:This is a warning
# ERROR:MyLogger:This is an error

# %%
## 19 Write a program that handles both IndexError and KeyError using a try-except block.

# Sample list and dictionary
my_list = [10, 20, 30]
my_dict = {"name": "Alice", "age": 25}

try:
    # Attempt to access an invalid list index
    print("Accessing list element:", my_list[5])

    # Attempt to access a non-existent dictionary key
    print("Accessing dictionary key:", my_dict["city"])

except IndexError:
    print("Error: List index out of range!")

except KeyError:
    print("Error: Dictionary key does not exist!")
# Out:
# Error: List index out of range!

# %%
## 20 How would you open a file and read its contents using a context manager in Python.


with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, world!
# This is a new line.
# Another line added.
# This is a new line.
# Another line added.

# %%
## 21 Write a Python program that reads a file and prints the number of occurrences of a specific word.

filename = "example.txt"
word_to_count = "Python"

try:
    with open(filename, "r") as file:
        content = file.read()

    count = content.lower().count(word_to_count.lower())

    print(f"The word '{word_to_count}' occurs {count} times in the file.")

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# The word 'Python' occurs 0 times in the file.

# %%
## 22 How can you check if a file is empty before attempting to read its contents.

import os

filename = "example.txt"

# Check if file exists and is not empty
if os.path.exists(filename) and os.path.getsize(filename) > 0:
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"The file '{filename}' is empty or does not exist.")
# Out:
# Hello, world!
# This is a new line.
# Another line added.
# This is a new line.
# Another line added.

# %%
## 23 Write a Python program that writes to a log file when an error occurs during file handling.

import logging

logging.basicConfig(filename="file_errors.log", level=logging.ERROR)

filename = "example.txt"

try:

    with open(filename, "r") as file:
        content = file.read()
        print(content)

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
    logging.error(f"The file '{filename}' does not exist.")
# Out:
# Hello, world!
# This is a new line.
# Another line added.
# This is a new line.
# Another line added.
